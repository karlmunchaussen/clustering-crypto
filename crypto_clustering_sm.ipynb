# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import pandas as pd
# import hvplot.pandas
from pathlib import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Additional dependencies for plotting in SageMaker
# !pip install -U altair
# Out:
# Requirement already up-to-date: altair in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.0.1)
# Requirement not upgraded as not directly required: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (2.6.0)
# Requirement not upgraded as not directly required: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (2.10)
# Requirement not upgraded as not directly required: entrypoints in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.2.3)
# Requirement not upgraded as not directly required: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.14.3)
# Requirement not upgraded as not directly required: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.24.2)
# Requirement not upgraded as not directly required: toolz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.9.0)
# Requirement not upgraded as not directly required: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->altair) (1.0)
# Requirement not upgraded as not directly required: python-dateutil>=2.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->altair) (2.7.3)
# Requirement not upgraded as not directly required: pytz>=2011k in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->altair) (2018.4)
# Requirement not upgraded as not directly required: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->altair) (1.11.0)
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import altair as alt

# %% [markdown]
# ### Data Preprocessing

# %%
# Load the cryptocurrencies data
file_path = Path("crypto_data.csv")
crypto_df = pd.read_csv(file_path, index_col=0)
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Check dtypes
crypto_df.dtypes
# Out:
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
# Check value counts
crypto_df['IsTrading'].value_counts()
# Out:
# True     1144
# False     108
# Name: IsTrading, dtype: int64

# %%
# Keep only cryptocurrencies that are on trading
index_names = crypto_df[crypto_df['IsTrading'] == False].index

crypto_df.drop(index_names, inplace=True)

# %%
# Check value counts
crypto_df['IsTrading'].value_counts()
# Out:
# True    1144
# Name: IsTrading, dtype: int64

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df.isnull().sum()
# Out:
# CoinName             0
# Algorithm            0
# IsTrading            0
# ProofType            0
# TotalCoinsMined    459
# TotalCoinSupply      0
# dtype: int64

# %%
# Remove the "IsTrading" column
crypto_df.drop('IsTrading', axis = 1, inplace=True)

# %%
# Remove rows with at least 1 null value
crypto_df.dropna(inplace=True)

# %%
# Remove rows with cryptocurrencies without coins mined
index_names = crypto_df[crypto_df['TotalCoinsMined'] == 0].index

crypto_df.drop(index_names, inplace=True)

# %%
# Fetch the cryptocurrencies names prior to drop them from crypto_df
coin_names = crypto_df['CoinName']

# %%
# Remove the cryptocurrency name since it's not going to be used on the clustering algorithm
crypto_df.drop('CoinName', axis = 1, inplace=True)

# %%
crypto_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      Scrypt   PoW/PoS     4.199995e+01              42
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337       X13   PoW/PoS     2.927942e+10    314159265359
# BTC    SHA-256       PoW     1.792718e+07        21000000
# ETH     Ethash       PoW     1.076842e+08               0

# %%
# Convert dtype
crypto_df['TotalCoinSupply'] = crypto_df['TotalCoinSupply'].astype(float)

# %%
# Create dummies variables for text features
crypto_df_enc = crypto_df.copy()

crypto_df_enc = pd.get_dummies(
    crypto_df_enc, 
    columns=['Algorithm', 'ProofType'],
    drop_first=True
)

crypto_df_enc.head()
# Out:
#       TotalCoinsMined  TotalCoinSupply  Algorithm_536  Algorithm_Argon2d  \
# 42       4.199995e+01     4.200000e+01              0                  0
# 404      1.055185e+09     5.320000e+08              0                  0
# 1337     2.927942e+10     3.141593e+11              0                  0
# BTC      1.792718e+07     2.100000e+07              0                  0
# ETH      1.076842e+08     0.000000e+00              0                  0
#
#       Algorithm_BLAKE256  Algorithm_Blake  Algorithm_Blake2S  \
# 42                     0                0                  0
# 404                    0                0                  0
# 1337                   0                0                  0
# BTC                    0                0                  0
# ETH                    0                0                  0
#
#       Algorithm_Blake2b  Algorithm_C11  Algorithm_Cloverhash  ...  \
# 42                    0              0                     0  ...
# 404                   0              0                     0  ...
# 1337                  0              0                     0  ...
# BTC                   0              0                     0  ...
# ETH                   0              0                     0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTC                   0                   0                  0
# ETH                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTC                    0              0                             0
# ETH                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTC                          0               0
# ETH                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# ETH                                0                   0
#
# [5 rows x 98 columns]

# %%
crypto_df_enc.shape
# Out:
# (533, 98)

# %%
# Standardize data
crypto_df_enc_scaled = StandardScaler().fit_transform(crypto_df_enc)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning:
#
# Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning:
#
# Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimension to 3 principal components
pca = PCA(n_components=3)

crypto_pca = pca.fit_transform(crypto_df_enc_scaled)

# %%
# Create a DataFrame with the principal components data
crypto_pca_df = pd.DataFrame(
    data=crypto_pca, 
    columns=["PC1", "PC2", "PC3"],
    index=crypto_df.index
)

crypto_pca_df.head()
# Out:
#            PC1       PC2       PC3
# 42   -0.323181  1.019952 -0.570899
# 404  -0.306497  1.019984 -0.571337
# 1337  2.300751  1.580843 -0.701533
# BTC  -0.151349 -1.302064  0.196468
# ETH  -0.166018 -1.976599  0.355300

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
list_k = list(range(1, 11))

# Calculate the inertia for the range ok k values
for k in list_k:
    km = KMeans(n_clusters=k)
    km.fit(crypto_pca_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": list_k, "inertia": inertia}

df_elbow = pd.DataFrame(elbow_data)

# df_elbow.hvplot.line(x="k", y="inertia", xticks=list_k, title="Elbow Curve")

alt.Chart(df_elbow).mark_line().encode(
    x='k',
    y='inertia'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Running K-Means with `k=4`

# %%
# Initialize the K-Means model
model = KMeans(
    n_clusters=4,
    random_state=42
)

# Fit the model
model.fit(crypto_pca_df)
# Predict clusters
predictions = model.predict(crypto_pca_df)

# Add clusters column
crypto_pca_df["cluster"] = model.labels_

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies feature
crypto_clustered_df = pd.concat([crypto_df, crypto_pca_df], axis = 1)

# %%
# Add coin names back
crypto_clustered_df.insert(0, 'CoinName', coin_names)

crypto_clustered_df.head()
# Out:
#        CoinName Algorithm ProofType  TotalCoinsMined  TotalCoinSupply  \
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01     4.200000e+01
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09     5.320000e+08
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10     3.141593e+11
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07     2.100000e+07
# ETH    Ethereum    Ethash       PoW     1.076842e+08     0.000000e+00
#
#            PC1       PC2       PC3  cluster
# 42   -0.323181  1.019952 -0.570899        1
# 404  -0.306497  1.019984 -0.571337        1
# 1337  2.300751  1.580843 -0.701533        1
# BTC  -0.151349 -1.302064  0.196468        0
# ETH  -0.166018 -1.976599  0.355300        0

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters
'''
fig = px.scatter_3d(
    crypto_clustered_df,
    x="PC3",
    y="PC2",
    z="PC1",
    hover_name = coin_names,
    hover_data = ["Algorithm"],
    width=800,
)

fig.update_layout(legend=dict(x=0, y=1))
fig.show()
'''

alt.Chart(crypto_clustered_df).mark_circle(size=60).encode(
    x='PC1',
    y='PC2',
    color = alt.Color('cluster:O',
        scale=alt.Scale(
        domain=['0', '1', '3', '4'],
        range=['red', 'green', 'yellow', 'black'])),
    tooltip=['CoinName:O', 'Algorithm:O', 'TotalCoinsMined:N', 'TotalCoinSupply:N']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
# crypto_clustered_df.hvplot.table(columns=['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 
#                                 'TotalCoinsMined','cluster'], width=800)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(crypto_clustered_df)
# Out:
#                                 CoinName               Algorithm  \
# 42                               42 Coin                  Scrypt
# 404                              404Coin                  Scrypt
# 1337                           EliteCoin                     X13
# BTC                              Bitcoin                 SHA-256
# ETH                             Ethereum                  Ethash
# LTC                             Litecoin                  Scrypt
# DASH                                Dash                     X11
# XMR                               Monero          CryptoNight-V7
# ETC                     Ethereum Classic                  Ethash
# ZEC                                ZCash                Equihash
# BTS                            Bitshares                 SHA-512
# DGB                             DigiByte                Multiple
# BTCD                         BitcoinDark                 SHA-256
# XPY                              PayCoin                 SHA-256
# PRC                          ProsperCoin                  Scrypt
# KOBO                            KoboCoin                     X15
# SPR                           Spreadcoin                     X11
# ARG                             Argentum                  Scrypt
# AUR                          Aurora Coin                  Scrypt
# BLU                             BlueCoin                  Scrypt
# XMY                           MyriadCoin                Multiple
# MOON                            MoonCoin                  Scrypt
# ZET                             ZetaCoin                 SHA-256
# SXC                              SexCoin                  Scrypt
# QTL                              Quatloo                  Scrypt
# ENRG                          EnergyCoin                  Scrypt
# QRK                            QuarkCoin                   Quark
# RIC                              Riecoin                 Groestl
# DGC                         Digitalcoin                   Scrypt
# BTB                               BitBar                  Scrypt
# CAT                              Catcoin                  Scrypt
# CBX                        CryptoBullion                  Scrypt
# CCN                            CannaCoin                  Scrypt
# CRYPT                          CryptCoin                     X11
# CSC                           CasinoCoin                  Scrypt
# DMD                              Diamond                 Groestl
# XVG                                Verge                Multiple
# DVC                              DevCoin                 SHA-256
# EAC                            EarthCoin                  Scrypt
# EFL                             E-Gulden                  Scrypt
# EMC2                         Einsteinium                  Scrypt
# EMD                              Emerald                  Scrypt
# EXCL                      Exclusive Coin                     PoS
# FLT                          FlutterCoin                  Scrypt
# FRK                               Franko                  Scrypt
# FTC                          FeatherCoin               NeoScrypt
# GDC                            GrandCoin                  Scrypt
# GLC                           GlobalCoin                  Scrypt
# GLD                             GoldCoin                  Scrypt
# HBN                          HoboNickels                  Scrypt
# HYP                           HyperStake                     X11
# IFC                        Infinite Coin                  Scrypt
# IOC                               IOCoin                     X11
# IXC                               IXcoin                 SHA-256
# KGC                           KrugerCoin                  Scrypt
# LKY                            LuckyCoin                  Scrypt
# LTB                             Litebar                   Scrypt
# MAX                              MaxCoin                    SHA3
# MEC                             MegaCoin                  Scrypt
# MED                    MediterraneanCoin     HybridScryptHash256
# MINT                            MintCoin                  Scrypt
# MINC                             MinCoin                  Scrypt
# MZC                             MazaCoin                 SHA-256
# NAUT                       Nautilus Coin                  Scrypt
# NAV                              NavCoin                     X13
# NOBL                           NobleCoin                  Scrypt
# NMC                             Namecoin                 SHA-256
# NYAN                            NyanCoin                  Scrypt
# OPAL                            OpalCoin                     X13
# ORB                            Orbitcoin               NeoScrypt
# POT                              PotCoin                  Scrypt
# PXC                          PhoenixCoin                  Scrypt
# RDD                             Reddcoin                  Scrypt
# RPC                          RonPaulCoin                  Scrypt
# SBC                           StableCoin                  Scrypt
# SMC                            SmartCoin                  Scrypt
# SUPER                          SuperCoin                     X11
# SYNC                            SyncCoin                     X11
# SYS                              SysCoin                 SHA-256
# TES                            TeslaCoin                Multiple
# TGC                            TigerCoin                 SHA-256
# TIT                           TittieCoin                 PHI1612
# TOR                              TorCoin                     X11
# TRC                            TerraCoin                 SHA-256
# UNB                      UnbreakableCoin                 SHA-256
# UNO                           Unobtanium                 SHA-256
# URO                              UroCoin                     X11
# USDE                UnitaryStatus Dollar                  Scrypt
# UTC                            UltraCoin                  Scrypt
# VIA                              ViaCoin                  Scrypt
# VRC                             VeriCoin                  Scrypt
# VTC                             Vertcoin               Lyra2REv2
# WDC                            WorldCoin                  Scrypt
# XC                              X11 Coin                     X11
# XCR                               Crypti                Multiple
# XJO                            JouleCoin                 SHA-256
# XST                          StealthCoin                     X13
# ZCC                             ZCC Coin                  Scrypt
# BCN                             ByteCoin             CryptoNight
# XDN                         DigitalNote              CryptoNight
# BURST                          BurstCoin               Shabal256
# SJCX                           StorjCoin            Counterparty
# MONA                            MonaCoin                  Scrypt
# NTRN                             Neutron                 SHA-256
# FAIR                            FairCoin                 Groestl
# NLG                               Gulden                  Scrypt
# RBY                             RubyCoin                  Scrypt
# PTC                           PesetaCoin                  Scrypt
# KORE                                Kore                     X13
# WBB                      Wild Beast Coin                  Scrypt
# NOTE                              Dnotes                  Scrypt
# FLO                                  Flo                  Scrypt
# 8BIT                           8BIT Coin                  Scrypt
# STV                          Sativa Coin                     X13
# ABY                              ArtByte                  Scrypt
# FLDC                        Folding Coin        Stanford Folding
# U                                  Ucoin                     X11
# UIS                               Unitus                Multiple
# CYP                       CypherPunkCoin                   QuBit
# OMC                             OmniCron                  Scrypt
# VTR                             Vtorrent                  Scrypt
# GRE                            GreenCoin                  Scrypt
# XCN                           Cryptonite                  M7 POW
# MSC                           MasterCoin                  Scrypt
# SOON                            SoonCoin                 SHA-256
# 1CR                              1Credit                  Scrypt
# ISL                             IslaCoin                     X11
# NXS                                Nexus                    SHA3
# MARS                           MarsCoin                      X11
# CTO                               Crypto                 Lyra2RE
# ACP                     Anarchists Prime                 SHA-256
# DRZ                               Droidz                   QUAIT
# BSC                             BowsCoin                     X11
# SQL                          Squall Coin                     X11
# SONG                           Song Coin                  Scrypt
# ZNY                              BitZeny                  Scrypt
# DIGS                             Diggits                  Scrypt
# EXP                              Expanse                  Ethash
# CON                               Paycon                     X13
# SC                               Siacoin                 Blake2b
# EMC                             Emercoin                 SHA-256
# EGC                        EverGreenCoin                     X15
# MND                             MindCoin                     X11
# I0C                               I0coin                 SHA-256
# DCR                               Decred                BLAKE256
# RVR                        Revolution VR                  Scrypt
# HODL                            HOdlcoin  1GB AES Pattern Search
# EDRC                             EDRCoin                 SHA-256
# HTC                              Hitcoin                     X11
# GAME                         Gamecredits                  Scrypt
# DBIC                           DubaiCoin                 SHA-256
# DIEM                       CarpeDiemCoin                 SHA-256
# PWR                             PWR Coin                   NIST5
# BLRY                         BillaryCoin                  Scrypt
# GPU                             GPU Coin                  Scrypt
# ADZ                              Adzcoin                     X11
# SOIL                            SoilCoin                  Dagger
# YOC                               YoCoin                  Scrypt
# SIB                              SibCoin                 X11GOST
# ERC                           EuropeCoin                     X11
# ZEIT                            ZeitCoin                  Scrypt
# SWING                          SwingCoin                 SHA-256
# SAFEX                   SafeExchangeCoin                  Scrypt
# NEBU                      Nebuchadnezzar                     PoS
# FRN                               Francs                  Scrypt
# BOLI                         BolivarCoin                     X11
# XRA                             Ratecoin                     X11
# REV                               Revenu                 SHA-256
# CKC                            Clockcoin                 SHA-256
# VIP                           VIP Tokens                   NIST5
# BSD                              BitSend                     X11
# OMNI                                Omni                  Scrypt
# LIR                          Let it Ride                 POS 3.0
# PUT                            PutinCoin                  Scrypt
# IBANK                          iBankCoin                  Scrypt
# FRWC                      Frankywillcoin                  Scrypt
# MUDRA                          MudraCoin                     X13
# PIZZA                          PizzaCoin                     X11
# LC                         Lutetium Coin                     X11
# KMD                               Komodo                Equihash
# GB                            GoldBlocks                     X11
# CTC                           CarterCoin                  Scrypt
# KRB                                Karbo             CryptoNight
# BXT                            BitTokens                 SHA-256
# ZYD                            ZayedCoin                 SHA-256
# MST                          MustangCoin                     X11
# ZNE                             ZoneCoin                  Scrypt
# COVAL                  Circuits of Value                Multiple
# ROOT                            RootCoin                  Scrypt
# DOPE                            DopeCoin                  Scrypt
# BTCR                         BitCurrency                  Scrypt
# DLC                           DollarCoin                 SHA-256
# SCN                             Swiscoin                  Scrypt
# SH                              Shilling                  Scrypt
# BUZZ                            BuzzCoin                SHA-256D
# XPO                                Opair                     PoS
# PSB                              PesoBit                  Scrypt
# HALLO                     Halloween Coin                     X11
# XZC                                ZCoin                  Lyra2Z
# CFC                           CoffeeCoin                     PoS
# ROYAL                          RoyalCoin                     X13
# GNJ                         GanjaCoin V2                     X14
# TEAM                              TeamUP                     PoS
# LANA                            LanaCoin                SHA-256D
# ELE                           Elementrem                  Ethash
# ZCL                             ZClassic                Equihash
# ARK                                  ARK                    DPoS
# INSANE                        InsaneCoin                     X11
# KLC                             KiloCoin                  Scrypt
# ATX                            ArtexCoin                     X11
# EMB                            EmberCoin                     X13
# XEN                            XenixCoin                     X11
# FRE                             FreeCoin                     PoS
# PLNC                             PLNCoin                  Scrypt
# ARCO                        AquariusCoin                  Scrypt
# KURT                             Kurrent                     X11
# XCRE                             Creatio                     PoS
# ENT                             Eternity                     X11
# EUC                             Eurocoin                 SHA-256
# BCF                          BitcoinFast                  Scrypt
# XSN                             Stakenet                     X11
# BCCOIN                   BitConnect Coin                  Scrypt
# MONEY                          MoneyCoin                  Scrypt
# XNG                               Enigma                     X11
# XCI               Cannabis Industry Coin             CryptoNight
# RC                            Russiacoin                  Scrypt
# PND                            PandaCoin                  Scrypt
# UNITS                          GameUnits                  Scrypt
# GAKH                            GAKHcoin                  Scrypt
# ASAFE2                           Allsafe                   Quark
# LTCR                           LiteCreed                   QuBit
# OS76                          OsmiumCoin                  Scrypt
# BIC                           Bikercoins             CryptoNight
# HXX                             HexxCoin                 Lyra2RE
# KED                Klingon Empire Darsek                  Scrypt
# IOP                   Internet of People                 SHA-256
# KUSH                            KushCoin                     X11
# PRX                           Printerium                  Scrypt
# PAC                              PacCoin                     X11
# IMPCH                            Impeach                  Scrypt
# CTL                              Citadel          CryptoNight-V7
# ZBC                           Zilbercoin                  Scrypt
# FRST                           FirstCoin                  Scrypt
# BVC                           BeaverCoin                  Scrypt
# FIND                            FindCoin                     X13
# VLTC                           VaultCoin                     X11
# ZER                                 Zero                Equihash
# CHAT                            OpenChat                  Scrypt
# CDN                         Canada eCoin                  Scrypt
# ZOI                                 Zoin                 Lyra2RE
# RNS                            RenosCoin                  Scrypt
# DBIX                           DubaiCoin        Dagger-Hashimoto
# XVP                        VirtacoinPlus                     X11
# TAJ                              TajCoin                 Blake2S
# IMX                               Impact                     X11
# EB3                              EB3coin                  Scrypt
# ATMOS                              Atmos                     PoS
# HPC                            HappyCoin                     X11
# CXT                             Coinonat                   NIST5
# MCRN                          MacronCoin                     PoS
# RAIN                          Condensate                     X11
# IMS             Independent Money System                  Scrypt
# ARGUS                          ArgusCoin                  Scrypt
# LMC                             LomoCoin                  Scrypt
# PROC                         ProCurrency                 SHA-256
# XGR                          GoldReserve                     X11
# BENJI                         BenjiRolls                  Scrypt
# GRW                           GrowthCoin                  Scrypt
# ILC                               ILCoin                 SHA-256
# PHR                               Phreak                     PoS
# DEA                           Degas Coin                  Scrypt
# HTML5                         HTML5 Coin                     X15
# USC                 Ultimate Secure Cash                 SHA-256
# EQT                           EquiTrader                  Scrypt
# QTUM                                QTUM                 POS 3.0
# QRL             Quantum Resistant Ledger          CryptoNight-V7
# ESP                               Espers                     536
# DYN                              Dynamic                 Argon2d
# NANO                                Nano                 Blake2b
# CHAN                            ChanCoin              Cloverhash
# DCY                          Dinastycoin             CryptoNight
# DNR                             Denarius                   NIST5
# DP                          DigitalPrice                     X11
# VUC                    Virta Unique Coin                   NIST5
# BTPL                      Bitcoin Planet                   Skein
# UNIFY                              Unify                  Scrypt
# BRIT                            BritCoin                     X13
# SOCC                          SocialCoin                  Scrypt
# ARC                           ArcticCoin                     X11
# DAS                                  DAS                     X11
# LINDA                              Linda                  Scrypt
# XLC                           LeviarCoin             CryptoNight
# ONION                          DeepOnion                     X13
# BTX                              Bitcore             Time Travel
# GCN                             gCn Coin                  Scrypt
# SMART                          SmartCash                  Keccak
# SIGT                            Signatum     SkunkHash v2 Raptor
# ONX                                 Onix                     X11
# CRM                                Cream                   Skein
# BCH                         Bitcoin Cash                 SHA-256
# XMCC                             Monoeci                     X11
# DFT                            Draftcoin                  Scrypt
# VET                              Vechain   VeChainThor Authority
# SOJ                         Sojourn Coin                  Scrypt
# STCN                           Stakecoin                     PoS
# NYC                          NewYorkCoin                  Scrypt
# FRAZ                            FrazCoin                  Scrypt
# KRONE                          Kronecoin                  Scrypt
# ACC                               AdCoin                  Scrypt
# LINX                                Linx                  Scrypt
# XCXT                           CoinonatX                  Scrypt
# ETHD                       Ethereum Dark                  Scrypt
# SUMO                            Sumokoin             CryptoNight
# ODN                             Obsidian                 SHA-512
# ADA                              Cardano               Ouroboros
# REC                            Regalcoin                     X11
# BTCZ                            BitcoinZ                Equihash
# TZC                           TrezarCoin               NeoScrypt
# ELM                             Elements                     X11
# TER                        TerraNovaCoin                  Scrypt
# VIVO                           VIVO Coin               NeoScrypt
# RUP                                Rupee               Lyra2REv2
# BTG                         Bitcoin Gold                Equihash
# WOMEN                          WomenCoin                  Scrypt
# MAY                     Theresa May Coin                 SHA-256
# NAMO                            NamoCoin                   NIST5
# LUX                              LUXCoin                 PHI1612
# PIRL                                Pirl                  Dagger
# XIOS                                Xios                  Scrypt
# BTDX                        Bitcloud 2.0                   Quark
# EBST                              eBoost                  Scrypt
# KEK                              KekCoin                 POS 2.0
# BLHC                       BlackholeCoin                  Scrypt
# XIN                   Infinity Economics                 SHA-256
# PURA                                Pura                     X11
# INN                               Innova               NeoScrypt
# ELLA                             Ellaism                  Ethash
# GBX                               GoByte               NeoScrypt
# MAG                               Magnet                     X11
# TAU                           Lamden Tau                    DPoS
# ECA                              Electra                   NIST5
# BCD                      Bitcoin Diamond                     X13
# XSH                               SHIELD                Multiple
# CNBC                    Cash & Back Coin                  Scrypt
# XUN                            UltraNote             CryptoNight
# COAL                             BitCoal             CryptoNight
# DAXX                            DaxxCoin                  Ethash
# BWK                              Bulwark                   NIST5
# KLKS                            Kalkulus                   Quark
# AC3                                  AC3                     X11
# LTHN                             Lethean          CryptoNight-V7
# GER                           GermanCoin                  Scrypt
# LTCU                      LiteCoin Ultra                  Scrypt
# POP                          PopularCoin                  Scrypt
# PNX                             PhantomX                     X11
# PHO                               Photon                BLAKE256
# SUCR                               Sucre                     X11
# SPK                            SparksPay               NeoScrypt
# WAGE                            Digiwage                   Quark
# GUN                              GunCoin               NeoScrypt
# IRL                            IrishCoin                  Scrypt
# TROLL                          Trollcoin                  Scrypt
# LCP                        Litecoin Plus                  Scrypt
# MONK                      Monkey Project                     X11
# PCOIN                       Pioneer Coin                     X11
# UBTC                       UnitedBitcoin                 SHA-256
# ITZ                            Interzone                     C11
# TPAY                            TokenPay                 POS 3.0
# MCT     1717 Masonic Commemorative Token                  Ethash
# MBC                          My Big Coin                  Scrypt
# TRTL                          TurtleCoin             CryptoNight
# MUN                              MUNcoin               SkunkHash
# USX                Unified Society USDEX                  Scrypt
# NBR                          Niobio Cash             CryptoNight
# SSS                           ShareChain                  Scrypt
# TRF                           Travelflex                  Dagger
# KREDS                              KREDS               Lyra2REv2
# TOKC                          Tokyo Coin                     X13
# BBP                             BiblePay      Proof-of-BibleHash
# LCC                         LitecoinCash          SHA-256 + Hive
# FLIP                             BitFlip                  Scrypt
# LOT                            LottoCoin                  Scrypt
# CIF              Crypto Improvement Fund                     X11
# SPD                              Stipend                     C11
# POA                          Poa Network      Proof-of-Authority
# PUSHI                              Pushi                     X11
# ELP                             Ellerium                   XEVAN
# VLX                                Velox                  Scrypt
# ONT                             Ontology                    VBFT
# CLO                     Callisto Network                  Ethash
# TUBE                             BitTube             CryptoNight
# PSD                             Poseidon                  Scrypt
# ADK                         Aidos Kuneen                   IMesh
# BSX                             Bitspace                   NIST5
# BRIA                            Briacoin                  Scrypt
# IC                              Ignition                  Scrypt
# BTL                            Bitrolium                Equihash
# MEDIC                          MedicCoin                  Scrypt
# ALPS                     Alpenschillling                  Lyra2Z
# BITG                       Bitcoin Green          Green Protocol
# DEV                         Deviant Coin                     PoS
# ABJ                              Abjcoin                  Scrypt
# SEM                                Semux     Semux BFT consensus
# FTO                           FuturoCoin                     X11
# CARE                             Carebit                   Quark
# NZL                              Zealium                     PoS
# XMC                       Monero Classic             CryptoNight
# PROTON                            Proton                    X16R
# DEAL                           iDealCash                  Scrypt
# JUMP                            Jumpcoin                   NIST5
# INFX                             Infinex                 Lyra2RE
# XBI                    Bitcoin Incognito                   XEVAN
# KEC                                KEYCO                  Tribus
# HWC                        HollyWoodCoin                  Scrypt
# GIN                              GINcoin                  Lyra2Z
# PLTC                          PlatinCoin             CryptoNight
# LOKI                                Loki       CryptoNight Heavy
# NCP                          Newton Coin             CryptoNight
# SIC                            Swisscoin                  Scrypt
# XT3                                Xt3ch                  Scrypt
# MGD                             MassGrid    Jump Consistent Hash
# VIG                               TheVig                SHA-256D
# PLURA                          PluraCoin             CryptoNight
# EMAR                          EmaratCoin                  Scrypt
# DKD                               Dekado                     X15
# LYNX                                Lynx                  Scrypt
# POSQ                      Poseidon Quark                   Quark
# BWS                     BitcoinWSpectrum                 SHA-256
# MUSE                                Muse                    DPoS
# XMN                               Motion                    X16R
# PLUS1                        PlusOneCoin                 HMQ1725
# AXE                                  Axe                     X11
# TRVC                          Trivechain                    X16R
# DTEM                              Dystem                   Quark
# GIC                                Giant                   Quark
# PNY                           Peony Coin                  Scrypt
# ABS                        Absolute Coin               Lyra2REv2
# VITAE                              Vitae                   Quark
# HEX                              HexCoin                  Scrypt
# TPC                               TPCash                  Scrypt
# WEBC                            Webchain          CryptoNight-V7
# RYO                                  Ryo         Cryptonight-GPU
# URALS                         Urals Coin                   XEVAN
# QWC                           Qwertycoin       CryptoNight Heavy
# ARE                               ARENON                     X11
# EUNO                                EUNO                     X11
# MMO                              MMOCoin                  Scrypt
# KETAN                              Ketan                     PoS
# PPAI                         Project Pai                 SHA-256
# XDNA                                XDNA                  Keccak
# PAXEX                              PAXEX                     X11
# AZART                              Azart                     X11
# TSC                         ThunderStake                  Scrypt
# KCASH                              Kcash                 SHA-512
# XCG                              Xchange                    X16R
# AAC                    Acute Angle Cloud               ECC 256K1
# CRYP                         CrypticCoin                Equihash
# BTXC                         Bettex coin                   XEVAN
# ACM                             Actinium                  Lyra2Z
# BSV                           Bitcoin SV                 SHA-256
# BITM                            BitMoney                   XEVAN
# JMC                Junson Ming Chan Coin                     X11
# FRED                          FREDEnergy             CryptoNight
# HERB                            HerbCoin                   Quark
# UMO                   Universal Molecule                   Blake
# LIT                              Lithium                   Blake
# PIRATE                        PirateCash                Equihash
# EXO                               Exosis                  Exosis
# BLTG                         Block-Logic                  Scrypt
# OWC                                Oduwa                  Scrypt
# BEAM                                Beam                Equihash
# GALI                             Galilel                   Quark
# BTH                            Bithereum                Equihash
# CSPN                       Crypto Sports                   Quark
# CREDIT                            Credit                  Scrypt
# SLC                                SLICE                   QuBit
# DASHP                      Dash Platinum                     X11
# NSD                            Nasdacoin                  Scrypt
# BEET                         Beetle Coin                   XEVAN
# TTN                           Titan Coin                SHA-256D
# AWR                                Award                     X11
# BLAST                              BLAST                 SHA-256
# XRC                      Bitcoin Rhodium                     X13
# GLT                          GlobalToken                 SHA-256
# INSN                         Insane Coin                     X11
# ALX                                 ALAX                    DPoS
# LDOGE                           LiteDoge                  Scrypt
# SLR                            SolarCoin                  Scrypt
# TRK                            TruckCoin                     X11
# UFO                             UFO Coin               NeoScrypt
# OC                            OrangeCoin                  Scrypt
# BLC                            BlakeCoin                   Blake
# BITS                         BitstarCoin                  Scrypt
# NEOS                            NeosCoin                 SHA-256
# HYPER                          HyperCoin                  Scrypt
# PINK                            PinkCoin                     X11
# CESC                       Crypto Escudo                  Scrypt
# ADC                            AudioCoin                  Scrypt
# NKA                             IncaKoin                 SHA-256
# PIGGY                         Piggy Coin                     X11
# CRW                           Crown Coin                 SHA-256
# GEN                             Genstake                  Scrypt
# SMLY                          SmileyCoin                  Scrypt
# MI                            XiaoMiCoin                  Scrypt
# GRS                          Groestlcoin                 Groestl
# CPC                            CapriCoin                     X11
# CLUB                            ClubCoin                  Scrypt
# RADS                              Radium                     PoS
# BTA                                 Bata                  Scrypt
# PAK                              Pakcoin                  Scrypt
# CRB                           Creditbit                      X11
# OK                                OKCash                 SHA-256
# LSK                                 Lisk                    DPoS
# XHI                               HiCoin                  Scrypt
# XWC                            WhiteCoin                  Scrypt
# FSC                       FriendshipCoin               NeoScrypt
# FIII                                Fiii                SHA3-256
# J                               JoinCoin                Multiple
# TRI                       Triangles Coin                     X13
# VOLLAR                            Vollar         Equihash+Scrypt
# EOS                                  EOS                    DPoS
# RCC                        Reality Clash                  Ethash
# OXY                              Oxycoin                    DPoS
# TCH                            TigerCash                 SHA-256
# WAVES                              Waves              Leased POS
# PART                             Particl                     PoS
# BTT                           BitTorrent                   TRC10
# NXT                                  Nxt                     PoS
# ZEPH                              ZEPHYR                 SHA-256
# GAP                              Gapcoin                  Scrypt
# BDX                               Beldex             CryptoNight
# ZEN                              Horizen                Equihash
# XBC                          BitcoinPlus                  Scrypt
#
#                    ProofType  TotalCoinsMined  TotalCoinSupply        PC1  \
# 42                   PoW/PoS     4.199995e+01     4.200000e+01  -0.323181
# 404                  PoW/PoS     1.055185e+09     5.320000e+08  -0.306497
# 1337                 PoW/PoS     2.927942e+10     3.141593e+11   2.300751
# BTC                      PoW     1.792718e+07     2.100000e+07  -0.151349
# ETH                      PoW     1.076842e+08     0.000000e+00  -0.166018
# LTC                      PoW     6.303924e+07     8.400000e+07  -0.154783
# DASH                 PoW/PoS     9.031294e+06     2.200000e+07  -0.409748
# XMR                      PoW     1.720114e+07     0.000000e+00  -0.159501
# ETC                      PoW     1.133597e+08     2.100000e+08  -0.164458
# ZEC                      PoW     7.383056e+06     2.100000e+07  -0.149917
# BTS                      PoS     2.741570e+09     3.600571e+09  -0.295997
# DGB                      PoW     1.140622e+10     2.100000e+10   0.159866
# BTCD                 PoW/PoS     1.288862e+06     2.200000e+07  -0.318575
# XPY                      PoS     1.199533e+07     1.250000e+07  -0.274825
# PRC                      PoW     5.768310e+06     2.100000e+07  -0.155931
# KOBO                 PoW/PoS     2.554254e+07     3.500000e+08  -0.247607
# SPR                      PoW     1.114973e+07     2.000000e+07  -0.242706
# ARG                      PoW     1.220580e+07     6.400000e+07  -0.155547
# AUR                  PoW/PoS     1.813510e+07     1.676858e+07  -0.322840
# BLU                  PoW/PoS     6.354239e+08     0.000000e+00  -0.315408
# XMY                      PoW     1.688254e+09     2.000000e+09  -0.093875
# MOON                     PoW     8.800000e+01     3.840000e+11   2.569570
# ZET                      PoW     1.702044e+08     1.697956e+08  -0.148430
# SXC                      PoW     1.289410e+08     2.500000e+08  -0.152799
# QTL                      PoW     7.357795e+06     1.000000e+08  -0.155351
# ENRG                 PoW/PoS     1.230628e+08     0.000000e+00  -0.321676
# QRK                      PoW     2.595572e+08     2.470000e+08  -0.230884
# RIC                      PoW     4.954859e+07     8.400000e+07  -0.205045
# DGC                      PoW     3.344299e+07     4.816600e+07  -0.155400
# BTB                  PoW/PoS     4.257948e+04     5.000000e+05  -0.323177
# CAT                      PoW     7.219957e+06     2.100000e+07  -0.155913
# CBX                  PoW/PoS     1.039117e+06     1.000000e+06  -0.323161
# CCN                      PoW     4.703880e+06     1.314000e+07  -0.156000
# CRYPT                    PoW     4.996986e+06     1.800000e+07  -0.242796
# CSC                      PoC     4.000000e+10     4.000000e+10   0.740926
# DMD                  PoW/PoS     3.304488e+06     4.380000e+06  -0.373206
# XVG                      PoW     1.592953e+10     1.655500e+10   0.183645
# DVC                      PoW     1.877386e+10     2.100000e+10   0.226995
# EAC                      PoW     1.253902e+10     1.350000e+10   0.093057
# EFL                      PoW     2.091048e+07     2.100000e+07  -0.155746
# EMC2                     PoW     2.188719e+08     2.997925e+08  -0.151346
# EMD                      PoW     1.949679e+07     3.200000e+07  -0.155685
# EXCL                     PoS     5.679705e+06     0.000000e+00  -0.356415
# FLT              PoS/PoW/PoT     4.618299e+08     0.000000e+00  -0.226968
# FRK                      PoW     1.142732e+06     1.123581e+07  -0.156057
# FTC                      PoW     2.086691e+08     3.360000e+08  -0.176590
# GDC                      PoW     8.841258e+08     1.420610e+09  -0.135252
# GLC                      PoW     6.567272e+07     7.000000e+07  -0.154851
# GLD                      PoW     4.165865e+07     7.224570e+07  -0.155128
# HBN                  PoW/PoS     8.926693e+07     1.200000e+08  -0.321237
# HYP                      PoS     1.678520e+09     0.000000e+00  -0.345795
# IFC                      PoW     9.059575e+10     9.060000e+10   1.595151
# IOC                  PoW/PoS     1.765091e+07     2.200000e+07  -0.409643
# IXC                      PoW     2.108935e+07     2.100000e+07  -0.151310
# KGC                      PoW     1.514476e+08     2.654208e+08  -0.152414
# LKY                      PoW     1.932632e+07     2.000000e+07  -0.155772
# LTB                      PoW     1.104344e+06     1.350000e+06  -0.156128
# MAX                  PoW/PoS     6.144580e+07     1.000000e+08  -0.419314
# MEC                      PoW     3.815200e+07     4.200000e+07  -0.155386
# MED                      PoW     4.043186e+07     2.000000e+08  -0.135210
# MINT                     PoS     2.129393e+10     0.000000e+00  -0.019018
# MINC                     PoW     5.804205e+06     1.000000e+07  -0.156009
# MZC                  PoW/PoS     1.613836e+09     2.419200e+09  -0.281834
# NAUT                     PoS     1.618000e+07     1.618000e+07  -0.279181
# NAV                  PoW/PoS     6.608710e+07     0.000000e+00  -0.286573
# NOBL                     PoW     2.366066e+09     1.500000e+10  -0.020735
# NMC                      PoW     1.473640e+07     2.100000e+07  -0.151388
# NYAN                     PoW     3.347092e+08     3.370000e+08  -0.149664
# OPAL                 PoW/PoS     1.515636e+07     0.000000e+00  -0.287196
# ORB                  PoW/PoS     3.220616e+06     3.770000e+06  -0.348492
# POT                  PoW/PoS     2.226772e+08     4.200000e+08  -0.317476
# PXC                  PoW/PoS     7.395927e+07     9.800000e+07  -0.321581
# RDD                  PoW/PoS     2.931557e+10     0.000000e+00   0.035418
# RPC                      PoW     1.104157e+06     2.100000e+07  -0.155988
# SBC                      PoW     2.421518e+07     2.500000e+08  -0.154080
# SMC                      PoW     2.559374e+07     5.120000e+07  -0.155474
# SUPER                    PoS     5.070766e+07     0.000000e+00  -0.365707
# SYNC                 PoW/PoS     1.177000e+03     1.000000e+03  -0.410015
# SYS                      PoW     5.633365e+08     8.880000e+08  -0.138523
# TES                      PoS     8.026046e+07     1.000000e+08  -0.250374
# TGC                      PoW     4.353680e+07     4.701197e+07  -0.150851
# TIT                      PoS     1.622326e+09     2.300000e+09  -0.327030
# TOR                  PoW/PoS     1.431851e+06     1.000000e+07  -0.409926
# TRC                      PoW     2.293540e+07     4.200000e+07  -0.151138
# UNB                      PoW     2.278150e+06     8.000000e+07  -0.151121
# UNO                      PoW     2.009118e+05     2.500000e+05  -0.151713
# URO                      PoW     1.207310e+06     0.000000e+00  -0.242970
# USDE                 PoW/PoS     1.098953e+09     1.600000e+09  -0.298381
# UTC                  PoW/PoS     5.023521e+07     1.000000e+08  -0.321857
# VIA                      PoW     2.315089e+07     2.300000e+07  -0.155704
# VRC                     PoST     3.202111e+07     0.000000e+00  -0.238449
# VTC                      PoW     5.117372e+07     8.400000e+07  -0.193059
# WDC                      PoW     1.196069e+08     2.654208e+08  -0.152804
# XC                   PoW/PoS     6.950831e+06     5.500000e+06  -0.409891
# XCR                      PoS     1.000000e+08     0.000000e+00  -0.250842
# XJO                      PoW     3.919574e+07     4.500000e+07  -0.150918
# XST                  PoW/PoS     3.309373e+07     0.000000e+00  -0.286977
# ZCC                  PoW/PoS     1.479902e+08     1.000000e+09  -0.314273
# BCN                      PoW     1.840668e+11     1.844674e+11   3.860339
# XDN                      PoW     6.906588e+09     1.000000e+10   0.454836
# BURST                    PoC     1.813034e+09     2.158813e+09   0.163600
# SJCX                     PoS     5.117314e+07     5.000000e+08  -0.354028
# MONA                     PoW     6.819467e+07     1.051200e+08  -0.154571
# NTRN                 PoW/PoS     3.912169e+07     6.800000e+07  -0.317786
# FAIR                 PoW/PoS     5.319383e+07     0.000000e+00  -0.372627
# NLG                      PoW     4.150324e+08     1.680000e+09  -0.139149
# RBY                      PoS     2.718449e+07     0.000000e+00  -0.279161
# PTC                      PoW     1.375177e+08     1.663860e+08  -0.153288
# KORE                 PoW/PoS     2.022465e+06     1.200000e+07  -0.287272
# WBB                      PoW     1.819192e+05     2.628000e+06  -0.156130
# NOTE                     PoS     1.746461e+08     5.000000e+08  -0.273808
# FLO                      PoW     1.522707e+08     1.600000e+08  -0.153153
# 8BIT                 PoW/PoS     1.467841e+06     0.000000e+00  -0.323163
# STV                  PoW/PoS     7.096834e+06     1.000000e+07  -0.287224
# ABY                      PoW     7.925372e+08     1.000000e+09  -0.139358
# FLDC                     PoW     7.194170e+08     1.000000e+09  -0.098370
# U                        PoS     2.689812e+06     2.000000e+07  -0.366153
# UIS                      PoW     6.511330e+07     0.000000e+00  -0.127926
# CYP                      PoW     6.365285e+06     0.000000e+00  -0.193075
# OMC                      PoW     1.014004e+07     3.371337e+06  -0.156003
# VTR                  PoW/PoS     1.160472e+07     2.000000e+07  -0.322897
# GRE                      PoW     4.610341e+09     1.000000e+10  -0.028773
# XCN                      PoW     7.085065e+08     1.840000e+09  -0.111661
# MSC                      PoW     6.194780e+05     6.194780e+05  -0.156139
# SOON                     PoW     1.246262e+07     2.100000e+07  -0.151416
# 1CR                      PoW     8.821300e+04     9.200000e+10   0.496887
# ISL                  PoW/PoS     1.513704e+06     0.000000e+00  -0.409996
# NXS                 PoW/nPoS     6.365722e+07     7.800000e+07  -0.422818
# MARS                     PoW     3.222157e+07     3.300000e+07  -0.242356
# CTO                      PoW     1.374274e+07     6.578910e+07  -0.155178
# ACP                      PoW     1.474720e+07     5.376000e+07  -0.151155
# DRZ                  PoW/PoS     8.568038e+06     5.060000e+06  -0.411425
# BSC                      PoW     1.586384e+07     2.100000e+07  -0.242641
# SQL                  PoS/PoW     3.292000e+05     0.000000e+00  -0.372116
# SONG                     PoW     3.256530e+07     2.102400e+08  -0.154260
# ZNY                      PoW     7.561450e+07     2.500000e+08  -0.153451
# DIGS                     PoS     1.000000e+08     1.000000e+08  -0.277561
# EXP                      PoW     1.049528e+07     1.690640e+07  -0.167087
# CON                  PoW/PoS     2.304260e+07     5.000000e+07  -0.286745
# SC                       PoW     3.309830e+10     0.000000e+00   0.362924
# EMC                  PoW/PoS     4.305979e+07     1.000000e+09  -0.311122
# EGC                  PoW/PoS     1.353056e+07     2.629800e+07  -0.250052
# MND                      PoW     1.586770e+07     1.600000e+07  -0.242677
# I0C                      PoW     2.099748e+07     2.100000e+07  -0.151311
# DCR                  PoW/PoS     1.036505e+07     2.100000e+07  -0.087501
# RVR                      PoW     2.100000e+08     2.100000e+08  -0.152091
# HODL                     PoW     1.144895e+07     8.196210e+07  -0.097741
# EDRC                 PoW/PoS     3.669692e+06     2.200000e+07  -0.318546
# HTC                  PoW/PoS     1.099632e+10     2.655000e+10  -0.087046
# GAME                     PoW     6.983610e+07     8.400000e+07  -0.154700
# ...
# MSC    -1.101554   0.028525        0
# SOON   -1.302066   0.196470        0
# 1CR    -1.154279   0.025664        0
# ISL     1.175660  -0.551787        1
# NXS     2.576288  -0.140670        1
# MARS   -0.945855   0.047623        0
# CTO    -2.192967   0.491553        0
# ACP    -1.302084   0.196468        0
# DRZ     1.864699  -0.728158        1
# BSC    -0.945854   0.047630        0
# SQL     0.662074  -0.317793        1
# SONG   -1.101664   0.028506        0
# ZNY    -1.101673   0.028487        0
# DIGS    0.856609  -0.260871        1
# EXP    -1.976640   0.355338        0
# CON     1.751497  -0.680081        1
# SC     -2.183083   0.468899        0
# EMC     0.818889  -0.402997        1
# EGC     1.811192  -0.644684        1
# MND    -0.945851   0.047630        0
# I0C    -1.302063   0.196467        0
# DCR     0.834042  -0.447684        1
# RVR    -1.101607   0.028435        0
# HODL   -1.147292   0.222648        0
# EDRC    0.819436  -0.402951        1
# HTC     1.163962  -0.557004        1
# GAME   -1.101580   0.028495        0
# DBIC    0.819444  -0.402951        1
# DIEM   -1.307497   0.187121        0
# PWR     1.371491  -0.579855        1
# BLRY    1.019931  -0.570904        1
# GPU     0.856520  -0.260851        1
# ADZ    -0.945880   0.047617        0
# SOIL   -2.186879   0.374404        0
# YOC    -1.101651   0.028520        0
# SIB    -2.226441   0.403776        0
# ERC     1.175443  -0.551803        1
# ZEIT    0.811726  -0.278671        1
# SWING   0.819426  -0.402951        1
# SAFEX   0.281787  -0.210315        1
# NEBU    1.667961  -0.186282        1
# FRN    -1.101564   0.028522        0
# BOLI   -0.945857   0.047631        0
# XRA     1.175659  -0.551843        1
# REV     0.819321  -0.402956        1
# CKC     0.819152  -0.402971        1
# VIP     1.368244  -0.575870        1
# BSD     1.175587  -0.551801        1
# OMNI   -1.101554   0.028525        0
# LIR     1.488696  -0.112003        1
# PUT     1.019066  -0.571286        1
# IBANK   1.019928  -0.570902        1
# FRWC    1.019926  -0.570942        1
# MUDRA   1.588088  -0.370007        1
# PIZZA  -0.945860   0.047636        0
# LC      1.012175  -0.241999        1
# KMD    -1.092582   0.155872        0
# GB      1.175636  -0.551795        1
# CTC     1.019914  -0.570919        1
# KRB    -2.350862   0.434906        0
# BXT     0.819436  -0.402949        1
# ZYD    -1.302062   0.196473        0
# MST     1.175658  -0.551787        1
# ZNE     1.019940  -0.570900        1
# COVAL  -1.831125   0.407990        0
# ROOT    1.019952  -0.570899        1
# DOPE   -1.101631   0.028473        0
# BTCR    0.856688  -0.260895        1
# DLC    -1.302061   0.196472        0
# SCN     0.442664  -0.320038        1
# SH     -1.101568   0.028520        0
# BUZZ    1.913908  -0.801778        1
# XPO     1.667947  -0.186305        1
# PSB     1.019962  -0.570912        1
# HALLO   1.174884  -0.551939        1
# XZC    -2.261749   0.473350        0
# CFC     1.667991  -0.186334        1
# ROYAL   1.588200  -0.370000        1
# GNJ     1.708506  -0.696855        1
# TEAM    1.667799  -0.186290        1
# LANA    1.915151  -0.794003        1
# ELE    -1.976640   0.355331        0
# ZCL    -1.959840   0.355088        0
# ARK     2.113010  -0.539863        1
# INSANE  1.175648  -0.551795        1
# KLC    -1.107222   0.028136        0
# ATX    -0.945870   0.047293        0
# EMB     1.780527  -0.716913        1
# XEN     1.175658  -0.551788        1
# FRE     1.667953  -0.186295        1
# PLNC    1.019935  -0.570907        1
# ARCO    1.019928  -0.570901        1
# KURT   -0.945958   0.047606        0
# XCRE    1.667961  -0.186282        1
# ENT     1.175627  -0.551791        1
# EUC     0.819440  -0.402954        1
# BCF     1.019939  -0.570908        1
# XSN     0.509363  -0.235600        1
# BCCOIN  1.019939  -0.570904        1
# MONEY   1.019582  -0.570923        1
# XNG     1.175657  -0.551787        1
# XCI    -2.350871   0.434908        0
# RC      1.019872  -0.570906        1
# PND     0.848818  -0.275342        1
# UNITS   1.019945  -0.570900        1
# GAKH    1.019951  -0.570900        1
# ASAFE2  1.478715  -0.176917        1
# LTCR    0.559608  -0.392327        1
# OS76   -1.101556   0.028525        0
# BIC    -2.350871   0.434905        0
# HXX    -2.192939   0.491559        0
# KED     1.019673  -0.570924        1
# IOP     0.819437  -0.402950        1
# KUSH    1.175656  -0.551789        1
# PRX     1.019944  -0.570904        1
# PAC    -1.002984   0.044313        0
# IMPCH   1.019939  -0.570899        1
# CTL    -2.215011   0.483896        0
# ZBC     0.856603  -0.260831        1
# FRST    0.365660  -0.243374        1
# BVC    -1.101555   0.028524        0
# FIND    1.588197  -0.370005        1
# VLTC   -0.946410   0.047594        0
# ZER    -1.959837   0.355087        0
# CHAT    1.019699  -0.571329        1
# CDN    -1.101580   0.028482        0
# ZOI    -2.192940   0.491552        0
# RNS     0.856626  -0.260843        1
# DBIX   -2.276632   0.568255        0
# XVP     1.175606  -0.551795        1
# TAJ     1.921046  -1.005778        1
# IMX     1.175632  -0.551834        1
# EB3    -1.103826   0.028375        0
# ATMOS   1.667938  -0.186321        1
# HPC     1.175609  -0.551798        1
# CXT    -0.753261   0.023585        0
# MCRN    1.667865  -0.186446        1
# RAIN    1.175412  -0.551851        1
# IMS     1.019941  -0.570901        1
# ARGUS   1.019936  -0.570900        1
# LMC     1.019379  -0.570930        1
# PROC    0.613180  -0.095250        1
# XGR     1.175642  -0.551795        1
# BENJI  -1.101568   0.028516        0
# GRW     0.855582  -0.261008        1
# ILC    -1.303069   0.195872        0
# PHR     1.667952  -0.186279        1
# DEA     1.019898  -0.570910        1
# HTML5   1.772632  -0.663714        1
# USC     0.656019  -0.092888        1
# EQT    -1.101591   0.028518        0
# QTUM    1.488677  -0.112030        1
# QRL    -2.214947   0.483875        0
# ESP     1.834965  -0.826872        1
# DYN    -2.263431   0.601559        0
# NANO   -2.193824   0.482053        0
# CHAN   -2.229812   0.449240        0
# DCY    -2.351426   0.434124        0
# DNR     1.368265  -0.575835        1
# DP     -0.945893   0.047620        0
# VUC     1.368220  -0.575862        1
# BTPL    1.867817  -0.776127        1
# UNIFY  -1.101559   0.028518        0
# BRIT    1.751508  -0.680079        1
# SOCC   -1.101596   0.028521        0
# ARC    -0.945873   0.047625        0
# DAS    -0.945857   0.047636        0
# LINDA   0.994191  -0.576066        1
# XLC    -2.350886   0.434902        0
# ONION   1.751515  -0.680079        1
# BTX    -2.214641   0.422878        0
# GCN    -1.164007  -0.042810        0
# SMART  -1.235163   0.164362        0
# SIGT    1.463947  -0.109757        1
# ONX    -0.946438   0.047554        0
# CRM     1.867830  -0.776143        1
# BCH    -1.302064   0.196468        0
# XMCC    1.175658  -0.551792        1
# DFT     0.856630  -0.260836        1
# VET     2.233329  11.812711        3
# SOJ    -1.107572   0.028199        0
# STCN    1.667932  -0.186277        1
# NYC    -1.055802  -0.028584        0
# FRAZ   -1.101563   0.028521        0
# KRONE  -1.101597   0.028516        0
# ACC    -1.101601   0.028509        0
# LINX   -1.101601   0.028509        0
# XCXT    1.019930  -0.570908        1
# ETHD    1.019951  -0.570900        1
# SUMO   -2.350907   0.434903        0
# ODN     1.600338   0.079577        1
# ADA     1.311678  -0.094503        1
# REC     1.175646  -0.551791        1
# BTCZ   -1.970197   0.352356        0
# TZC     0.464075  -0.337833        1
# ELM    -0.946013   0.046502        0
# TER     1.019943  -0.570900        1
# VIVO   -1.657274   0.261674        0
# RUP     0.710532  -0.082015        1
# BTG    -1.959836   0.355083        0
# WOMEN   1.021128  -0.591028        1
# MAY     0.819420  -0.402988        1
# NAMO    1.367761  -0.576095        1
# LUX     1.905225  -0.667614        1
# PIRL   -2.186942   0.374389        0
# XIOS    1.019940  -0.570900        1
# BTDX    1.641933  -0.487002        1
# EBST   -1.101580   0.028482        0
# KEK     1.538148  -0.178249        1
# BLHC    1.019948  -0.570906        1
# XIN     0.653852  -0.096752        1
# PURA   -0.945991   0.047556        0
# INN    -1.657284   0.261673        0
# ELLA   -1.976790   0.355329        0
# GBX    -1.657277   0.261673        0
# MAG     1.175589  -0.551806        1
# TAU     2.112853  -0.539947        1
# ECA     1.360162  -0.588108        1
# BCD     1.751457  -0.680150        1
# XSH    -1.830981   0.408214        0
# CNBC    1.019867  -0.570949        1
# XUN    -2.393403   0.424565        0
# COAL   -2.350865   0.434907        0
# DAXX   -1.982198   0.354824        0
# BWK     1.204940  -0.265769        1
# KLKS    1.478714  -0.176920        1
# AC3    -0.946136   0.047588        0
# LTHN   -2.215340   0.483699        0
# GER     0.992868  -0.574415        1
# LTCU    1.019868  -0.570907        1
# POP    -1.103151   0.026787        0
# PNX     1.175645  -0.551806        1
# PHO    -1.329407   0.136930        0
# SUCR   -0.945857   0.047635        0
# SPK    -1.657270   0.261673        0
# WAGE    1.478660  -0.176927        1
# GUN    -1.657451   0.261541        0
# IRL    -1.101576   0.028505        0
# TROLL   1.019625  -0.571163        1
# LCP     1.019950  -0.570900        1
# MONK    1.012331  -0.241718        1
# PCOIN  -0.945857   0.047633        0
# UBTC   -1.302063   0.196467        0
# ITZ    -1.339571   0.228122        0
# TPAY    1.488695  -0.111996        1
# MCT    -0.018446   0.065989        1
# MBC     0.404284  -0.221047        1
# TRTL   -2.906951   0.382587        0
# MUN    -2.303303   0.349854        0
# USX     1.019894  -0.571000        1
# NBR    -2.351009   0.434845        0
# SSS    -1.104086   0.024221        0
# TRF    -2.186887   0.374361        0
# KREDS  -1.248075   0.207058        0
# TOKC    1.587816  -0.370116        1
# BBP     4.013952  11.651734        3
# LCC     3.553557  12.391963        3
# FLIP   -1.101573   0.028519        0
# LOT    -1.107467   0.022166        0
# CIF    -0.946066   0.047537        0
# SPD     0.781937  -0.371302        1
# POA     3.457301  15.424611        3
# PUSHI   1.175646  -0.551788        1
# ELP     1.265616  -0.531221        1
# VLX     0.856571  -0.260842        1
# ONT     1.489036  -0.173535        1
# CLO    -1.980279   0.355042        0
# TUBE   -2.351407   0.434846        0
# PSD    -1.101565   0.028523        0
# ADK    -2.253259   0.453429        0
# BSX     1.368245  -0.575841        1
# BRIA    1.019950  -0.570899        1
# IC      1.019949  -0.570899        1
# BTL    -1.959847   0.355060        0
# MEDIC   0.856433  -0.260950        1
# ALPS   -2.261903   0.473334        0
# BITG    1.607459  -0.124174        1
# DEV     1.667923  -0.186285        1
# ABJ     1.019938  -0.570904        1
# SEM     2.158828  -0.461787        1
# FTO    -0.945894   0.047621        0
# CARE    1.641968  -0.487045        1
# NZL     1.667924  -0.186281        1
# XMC    -2.350865   0.434902        0
# PROTON  0.688052  -0.149085        1
# DEAL    1.017466  -0.571619        1
# JUMP   -0.753242   0.023582        0
# INFX   -2.192947   0.491557        0
# XBI     0.752056  -0.297230        1
# KEC    -2.338545   0.511047        0
# HWC     0.856631  -0.260844        1
# GIN    -2.261743   0.473351        0
# PLTC   -2.351203   0.434890        0
# LOKI   -2.245952   0.509833        0
# NCP    -2.443097   0.412696        0
# SIC     1.017369  -0.575289        1
# XT3     0.856611  -0.260832        1
# MGD    -2.240199   0.624709        0
# VIG     1.919060  -0.793354        1
# PLURA  -2.351253   0.434654        0
# EMAR    1.019910  -0.570910        1
# DKD     1.647843  -0.334622        1
# LYNX    0.236666  -0.395020        1
# POSQ    1.478349  -0.176934        1
# BWS     0.656091  -0.092904        1
# MUSE    1.826094  -0.338757        1
# XMN    -1.270122   0.140267        0
# PLUS1  -2.177261   0.356726        0
# AXE    -0.945857   0.047635        0
# TRVC    0.851359  -0.459170        1
# DTEM    1.478710  -0.176916        1
# GIC     1.642037  -0.486986        1
# PNY     0.846960  -0.261353        1
# ABS     0.873830  -0.392082        1
# VITAE   1.478684  -0.176942        1
# HEX    -1.101566   0.028524        0
# TPC     1.019380  -0.570932        1
# WEBC   -2.215907   0.483845        0
# RYO    -2.128078   0.380493        0
# URALS  -0.855971   0.068193        0
# QWC    -2.319741   0.464352        0
# ARE     1.012316  -0.241725        1
# EUNO    1.175641  -0.551801        1
# MMO     0.856519  -0.260879        1
# KETAN   1.667849  -0.186284        1
# PPAI   -1.302590   0.195572        0
# XDNA    0.888283  -0.434025        1
# PAXEX   1.012286  -0.241721        1
# AZART  -0.945859   0.047635        0
# TSC     1.009975  -0.571882        1
# KCASH   1.768175   0.490166        1
# XCG    -1.270166   0.140264        0
# AAC     0.230295   0.052469        1
# CRYP   -1.962830   0.353163        0
# BTXC    1.102306  -0.221152        1
# ACM    -2.261783   0.473346        0
# BSV    -1.302064   0.196468        0
# BITM    0.570808  -0.227898        1
# JMC     1.017847  -0.248589        1
# FRED   -2.354892   0.433912        0
# HERB    1.642018  -0.486999        1
# UMO    -2.211558   0.506336        0
# LIT    -2.211508   0.506333        0
# PIRATE -0.001698   0.065729        1
# EXO    -1.878987   0.253266        0
# BLTG   -1.101612   0.028508        0
# OWC     1.019944  -0.570905        1
# BEAM   -1.959969   0.355068        0
# GALI    1.642033  -0.486991        1
# BTH    -1.959839   0.355080        0
# CSPN    1.478713  -0.176914        1
# CREDIT  0.986946  -0.585535        1
# SLC    -1.561915   0.207103        0
# DASHP   1.012330  -0.241717        1
# NSD     1.019910  -0.570909        1
# BEET    1.265428  -0.531314        1
# TTN     1.916528  -0.793851        1
# AWR     1.175424  -0.551806        1
# BLAST  -1.302078   0.196453        0
# XRC    -0.369988  -0.080646        0
# GLT    -1.302127   0.196437        0
# INSN    1.175650  -0.551797        1
# ALX     2.112794  -0.540246        1
# LDOGE   1.004794  -0.578105        1
# SLR    -1.157757   0.025452        0
# TRK     1.175737  -0.551884        1
# UFO    -1.658329   0.260025        0
# OC      1.019838  -0.570906        1
# BLC    -2.215503   0.506113        0
# BITS    1.019927  -0.570909        1
# NEOS    0.656119  -0.092880        1
# HYPER   1.019955  -0.570902        1
# PINK    1.175512  -0.551977        1
# CESC   -1.101878   0.028183        0
# ADC     1.014248  -0.571617        1
# NKA     0.825078  -0.410118        1
# PIGGY   1.175244  -0.552015        1
# CRW    -1.302075   0.196465        0
# GEN     1.019962  -0.570923        1
# SMLY   -1.120744   0.015156        0
# MI      1.019852  -0.571073        1
# GRS    -1.285800   0.235452        0
# CPC     1.175605  -0.551874        1
# CLUB    1.019893  -0.570945        1
# RADS    1.667962  -0.186275        1
# BTA    -1.101555   0.028523        0
# PAK    -1.101636   0.028492        0
# CRB     0.733477  -0.419128        1
# OK      0.819412  -0.402981        1
# LSK     2.112994  -0.539869        1
# XHI     0.854097  -0.265133        1
# XWC     1.019860  -0.571009        1
# FSC     0.464212  -0.337750        1
# FIII    3.934474  10.653338        3
# J      -1.830758   0.408426        0
# TRI     1.751519  -0.680070        1
# VOLLAR -2.314181   0.595203        0
# EOS     2.113373  -0.540224        1
# RCC    -1.976640   0.355332        0
# OXY     2.113406  -0.540264        1
# TCH     0.655877  -0.093308        1
# WAVES   2.338758  14.358229        3
# PART    1.667964  -0.186278        1
# BTT     1.643232  -1.380633        2
# NXT     2.079680  -0.394030        1
# ZEPH    0.942573  -0.294805        1
# GAP     1.019813  -0.570912        1
# BDX    -2.351348   0.434474        0
# ZEN    -1.959840   0.355087        0
# XBC     0.856633  -0.260828        1

# %%
# Print the total number of tradable cryptocurrencies
print(f'There are {crypto_clustered_df.cluster.count()} tradable cryptos')
# Out:
# There are 533 tradable cryptos

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
crypto_clustered_df.plot(kind='scatter', x = 'TotalCoinsMined', y = 'TotalCoinSupply')
